# %% [markdown]
# ## Assignment 08 - Kafka Consumer
#
# <br>Author: Anjani Bonda
# <br>Date: 5/6/2023

# %%
# Load necessary/required libraries
import pandas as pd
import json
from kafka import KafkaConsumer

# %% [markdown]
# ### Configuration Parameters

# %%
config = dict(
    bootstrap_servers=['kafka.kafka.svc.cluster.local:9092'],
    first_name='Anjani',
    last_name='Bonda'
)

config['client_id'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)
config['topic_prefix'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)

config
# Out:
# {'bootstrap_servers': ['kafka.kafka.svc.cluster.local:9092'],
#  'first_name': 'Anjani',
#  'last_name': 'Bonda',
#  'client_id': 'BondaAnjani',
#  'topic_prefix': 'BondaAnjani'}

# %% [markdown]
# #### Create a consumer without subscribing to any particular topic

# %%
general_consumer = KafkaConsumer(
    bootstrap_servers=config['bootstrap_servers']
)

# %%
# List all topics you are currently allowed to view
general_consumer.topics()
# Out:
# {'AvinazGabriel-accelerations',
#  'AvinazGabriel-locations',
#  'BondaAnjani-accelerations',
#  'BondaAnjani-locations',
#  'ChristudassReenie-accelerations',
#  'ChristudassReenie-locations',
#  'ClaytonDan-joined',
#  'ClaytonDan-simple',
#  'ClaytonDan-windowed',
#  'ClaytonDaniel-accelerations',
#  'ClaytonDaniel-locations',
#  'ClaytonDaniel-simple',
#  'CosentiniVictor-accelerations',
#  'CosentiniVictor-locations',
#  'DoeJohn-accelerations',
#  'DoeJohn-locations',
#  'DoeJohn-windowed',
#  'GreenertJosh-accelerations',
#  'GreenertJosh-locations',
#  'HanPhil-accelerations',
#  'HanPhil-locations',
#  'MeyerJake-acceleration',
#  'MeyerJake-accelerations',
#  'MeyerJake-locations',
#  'OehlerAngie-accelerations',
#  'OehlerAngie-locations',
#  'Oehler_Angie-locations',
#  'OmprakashSantosh-accelerations',
#  'OmprakashSantosh-locations',
#  'PashShaq-accelerations',
#  'PashShaq-locations',
#  'PatelMithil-accelerations',
#  'PatelMithil-locations',
#  'ShermanMilan-accelerations',
#  'ShermanMilan-locations',
#  'ShermanMilan-simple',
#  'TabbalatAbed-accelerations',
#  'TabbalatAbed-locations',
#  'TabbalatAbed-simple',
#  'TranQua-accelerations',
#  'TranQua-joined',
#  'TranQua-locations',
#  'TranQua-simple',
#  'TranQua-windowed',
#  'VayuvegulaSomaShekar-accelerations',
#  'VayuvegulaSomaShekar-locations',
#  'WeatherfordPatrick-accelerations',
#  'WeatherfordPatrick-locations'}

# %%
# Close the consumer, waiting indefinitely for any needed cleanup.
general_consumer.close()

# %% [markdown]
# ### Define kafka consumer

# %%
def create_kafka_consumer(topics, config=config):
    bootstrap_servers = config['bootstrap_servers']
    client_id = config['client_id']
    topic_prefix = config['topic_prefix']    
    topic_list = ['{}-{}'.format(topic_prefix, topic) for topic in topics]
    
    return KafkaConsumer(
        *topic_list,
        client_id=client_id,
        bootstrap_servers=bootstrap_servers,
        auto_offset_reset='earliest',
        enable_auto_commit=False,
        value_deserializer=lambda x: json.loads(x)
    )

consumer = create_kafka_consumer(['locations', 'accelerations'])

# %%
# Gets a list of this consumer's current subscriptions
consumer.subscription()
# Out:
# {'BondaAnjani-accelerations', 'BondaAnjani-locations'}

# %% [markdown]
# The following function prints messages from the current consumer subscriptions. It will continue until manually stopped.

# %%
# The following function prints messages from the current consumer subscriptions. 
# It will continue until manually stopped.

def print_messages(consumer=consumer):
    try:
        for message in consumer:
                msg_metadata = 'Message metadata: {}:{}:{}'.format(
                    message.topic, message.partition, message.offset
                )

                if message.key is not None:
                    msg_key = message.key.decode('utf-8')
                else:
                    msg_key = ''
                msg_value = json.dumps(message.value, indent=2)
                msg_value = '\n'.join(['  {}'.format(value) for value in msg_value.split('\n')])

                print('Message metadata:')
                print('  Topic: {}'.format(message.topic))
                print('  Partition: {}'.format(message.partition))
                print('  Offset: {}'.format(message.offset))
                print('Message Key: {}'.format(msg_key))
                print('Message Value:')
                print(msg_value)
                print()
    except KeyboardInterrupt:
        print("STOPPING MESSAGE CONSUMER")

print_messages()
# Out:
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 0
# Message Key: 000.0
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320452",
#     "offset": 1.5319125295566454,
#     "x": -0.974,
#     "y": -0.132,
#     "z": -0.194,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 1
# Message Key: 004.5
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320448",
#     "offset": 5.437912529556645,
#     "x": -0.891,
#     "y": 0.082,
#     "z": -0.054,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 2
# Message Key: 007.8
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320445",
#     "offset": 8.698912529556646,
#     "x": -0.897,
#     "y": 0.032,
#     "z": -0.032,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 3
# Message Key: 010.6
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320441",
#     "offset": 12.193912529556645,
#     "x": -0.963,
#     "y": -0.022,
#     "z": 0.04,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 4
# Message Key: 014.9
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320438",
#     "offset": 16.038912529556647,
#     "x": -1.053,
#     "y": 0.04,
#     "z": 0.066,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 5
# Message Key: 017.9
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320435",
#     "offset": 18.673912529556645,
#     "x": -0.997,
#     "y": 0.19,
#     "z": 0.106,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 6
# Message Key: 021.3
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320431",
#     "offset": 22.714912529556646,
#     "x": -1.052,
#     "y": -0.033,
#     "z": -0.096,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 7
# Message Key: 026.1
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320426",
#     "offset": 27.438912529556646,
#     "x": -1.147,
#     "y": -0.093,
#     "z": -0.095,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 8
# Message Key: 030.4
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320422",
#     "offset": 32.04691252955664,
#     "x": -1.064,
#     "y": 0.001,
#     "z": 0.055,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 9
# Message Key: 033.7
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320418",
#     "offset": 35.26791252955665,
#     "x": -0.971,
#     "y": -0.226,
#     "z": 0.108,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 10
# Message Key: 037.7
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320415",
#     "offset": 38.99591252955665,
#     "x": -0.998,
#     "y": 0.07200000000000001,
#     "z": 0.051000000000000004,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 11
# Message Key: 041.5
# Message Value:
#   {
#     "id": "c44516bd325cb60548b431b4d6409dde",
#     "ride_id": "b063cb65cd8446b83b4a09d4db2646c8",
#     "uuid": "c6608d4cb9224aa3a0763a835e6c8788",
#     "timestamp": "1970-01-01 00:25:06.796338",
#     "offset": 42.9477702566351,
#     "x": -1.076,
#     "y": -0.019,
#     "z": -0.133,
#     "timelapse": false,
#     "filename": "0d4d27dc-360b-4bb2-9b0c-bf84be964785.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 12
# Message Key: 045.4
# Message Value:
#   {
#     "id": "c44516bd325cb60548b431b4d6409dde",
#     "ride_id": "b063cb65cd8446b83b4a09d4db2646c8",
#     "uuid": "c6608d4cb9224aa3a0763a835e6c8788",
#     "timestamp": "1970-01-01 00:25:06.796334",
#     "offset": 46.9877702566351,
#     "x": -0.977,
#     "y": 0.02,
#     "z": 0.011,
#     "timelapse": false,
#     "filename": "0d4d27dc-360b-4bb2-9b0c-bf84be964785.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 13
# Message Key: 049.5
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471334",
#     "offset": 50.57891734364177,
#     "x": 1.03,
#     "y": 0.015,
#     "z": 0.016,
#     "timelapse": false,
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset:

#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 57
# Message Key: 085.1
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533237",
#     "offset": 85.83587096575218,
#     "x": -0.982,
#     "y": 0.041,
#     "z": 0.014,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 58
# Message Key: 088.3
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533234",
#     "offset": 89.15787096575218,
#     "x": -0.97,
#     "y": 0.02,
#     "z": -0.056,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 59
# Message Key: 091.7
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533231",
#     "offset": 92.57887096575219,
#     "x": -1.046,
#     "y": -0.01,
#     "z": 0.133,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 60
# Message Key: 094.7
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533227",
#     "offset": 95.82087096575219,
#     "x": -1.0,
#     "y": -0.003,
#     "z": 0.062,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 61
# Message Key: 098.8
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533223",
#     "offset": 99.74287096575219,
#     "x": -0.979,
#     "y": 0.005,
#     "z": -0.1,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 62
# Message Key: 102.5
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256867",
#     "offset": 104.01892680518745,
#     "x": -0.9510000000000001,
#     "y": -0.03,
#     "z": -0.517,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 63
# Message Key: 106.0
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256863",
#     "offset": 107.46592680518745,
#     "x": -1.006,
#     "y": -0.107,
#     "z": -0.066,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 64
# Message Key: 109.9
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256860",
#     "offset": 110.71492680518745,
#     "x": -0.8220000000000001,
#     "y": -0.061,
#     "z": -0.158,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 65
# Message Key: 113.2
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256856",
#     "offset": 114.79992680518745,
#     "x": -1.029,
#     "y": -0.099,
#     "z": -0.064,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 66
# Message Key: 117.2
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256853",
#     "offset": 118.28792680518745,
#     "x": -0.977,
#     "y": -0.058,
#     "z": -0.121,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-accelerations
#   Partition: 0
#   Offset: 67
# Message Key: 121.4
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256848",
#     "offset": 122.45392680518745,
#     "x": -0.98,
#     "y": -0.046,
#     "z": -0.049,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 0
# Message Key: 000.0
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320453",
#     "offset": 1.0779125295566454,
#     "course": 158.203125,
#     "latitude": 40.677641336844,
#     "longitude": -73.81793000742218,
#     "geohash": "dr5x2jpkmtcy",
#     "speed": 2.119999885559082,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 1
# Message Key: 004.5
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320449",
#     "offset": 5.077912529556645,
#     "course": 159.9609375,
#     "latitude": 40.67788281947438,
#     "longitude": -73.81804710260948,
#     "geohash": "dr5x2jpmfffw",
#     "speed": 11.75,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 2
# Message Key: 007.8
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320446",
#     "offset": 8.077912529556645,
#     "course": 159.609375,
#     "latitude": 40.67819106396351,
#     "longitude": -73.81819261244854,
#     "geohash": "dr5x2jppxkqj",
#     "speed": 13.149999618530273,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 3
# Message Key: 010.6
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 12.077912529556645,
#     "course": 161.015625,
#     "latitude": 40.678637903221585,
#     "longitude": -73.81842395297608,
#     "geohash": "dr5x2jr44p9x",
#     "speed": 14.210000038146973,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 4
# Message Key: 014.9
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320439",
#     "offset": 15.077912529556645,
#     "course": 161.3671875,
#     "latitude": 40.67896198950771,
#     "longitude": -73.8185656909587,
#     "geohash": "dr5x2jqunspu",
#     "speed": 10.90999984741211,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 5
# Message Key: 017.9
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320436",
#     "offset": 18.077912529556645,
#     "course": 153.28125,
#     "latitude": 40.679180002809204,
#     "longitude": -73.81866442977807,
#     "geohash": "dr5x2jqvkky2",
#     "speed": 5.340000152587891,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 6
# Message Key: 021.3
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320432",
#     "offset": 22.077912529556645,
#     "course": 70.3125,
#     "latitude": 40.67922610327665,
#     "longitude": -73.81890138618073,
#     "geohash": "dr5x2jqtwvme",
#     "speed": 10.59000015258789,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 7
# Message Key: 026.1
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320427",
#     "offset": 27.077912529556645,
#     "course": 69.609375,
#     "latitude": 40.6790446769825,
#     "longitude": -73.81956908858737,
#     "geohash": "dr5x2jqhx7e9",
#     "speed": 12.069999694824219,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 8
# Message Key: 030.4
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320423",
#     "offset": 31.077912529556645,
#     "course": 67.5,
#     "latitude": 40.67889422182057,
#     "longitude": -73.82009002386948,
#     "geohash": "dr5x2jmgepx2",
#     "speed": 11.09000015258789,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 9
# Message Key: 033.7
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320419",
#     "offset": 35.07791252955665,
#     "course": 103.0078125,
#     "latitude": 40.678800176866986,
#     "longitude": -73.82046670659801,
#     "geohash": "dr5x2jme4myr",
#     "speed": 4.820000171661377,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 10
# Message Key: 037.7
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320416",
#     "offset": 38.07791252955665,
#     "course": 158.90625,
#     "latitude": 40.678862412498034,
#     "longitude": -73.82057458169183,
#     "geohash": "dr5x2jm7xctf",
#     "speed": 3.450000047683716,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 11
# Message Key: 041.5
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320412",
#     "offset": 42.07791252955665,
#     "course": 158.5546875,
#     "latitude": 40.67892904862825,
#     "longitude": -73.82060819312355,
#     "geohash": "dr5x2jm7zjuz",
#     "speed": 0.8700000047683716,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 12
# Message Key: 045.4
# Message Value:
#   {
#     "id": "c44516bd325cb60548b431b4d6409dde",
#     "ride_id": "b063cb65cd8446b83b4a09d4db2646c8",
#     "uuid": "c6608d4cb9224aa3a0763a835e6c8788",
#     "timestamp": "1970-01-01 00:25:06.796335",
#     "offset": 46.7677702566351,
#     "course": 36.619529724121094,
#     "latitude": 40.695276003407606,
#     "longitude": -73.92459313225648,
#     "geohash": "dr5rtb3g0jk1",
#     "speed": 11.010000228881836,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "0d4d27dc-360b-4bb2-9b0c-bf84be964785.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 13
# Message Key: 049.5
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471334",
#     "offset": 49.64691734364177,
#     "course": 218.3203125,
#     "latitude": 40.6138375355309,
#     "longitude": -73.98511720828151,
#     "geohash": "dr5rh3t8vb41",
#     "speed": 13.630000114440918,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 14
# Message Key: 052.5
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471330",
#     "offset": 53.64691734364177,
#     "course": 218.671875,
#     "latitude": 40.61420659072754,
#     "longitude": -73.98473197601174,
#     "geohash": "dr5rh3tfyuc7",
#     "speed": 12.350000381469727,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 15
# Message Key: 056.4
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471327",
#     "offset": 56.64691734364177,
#     "course": 217.6171875,
#     "latitude": 40.614466765001985,
#     "longitude": -73.98445554084515,
#     "geohash": "dr5rh3whmjr7",
#     "speed": 12.40999984741211,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 16
# Message Key: 060.1
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533263",
#     "offset": 60.62187096575219,
#     "course": 158.39361572265625,
#     "latitude": 40.79774731473191,
#     "longitude": -74.47818030692527,
#     "geohash": "dr7015n8he7d",
#     "speed": 0.0,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 17
# Message Key: 063.8
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533259",
#     "offset": 64.62187096575218,
#     "course": 158.39361572265625,
#     "latitude": 40.797748056487556,
#     "longitude": -74.47818069351581,
#     "geohash": "dr7015n8he7q",
#     "speed": 0.33000001311302185,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 18
# Message Key: 066.7
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533256",
#     "offset": 67.62187096575218,
#     "course": 157.17140197753906,
#     "latitude": 40.797799978465186,
#     "longitude": -74.47821074543842,
#     "geohash": "dr7015n87vhu",
#     "speed": 5.050000190734863,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 19
# Message Key: 070.9
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533252",
#     "offset": 71.62187096575218,
#     "course": 150.5653839111328,
#     "latitude": 40.797965233074194,
#     "longitude": -74.47836771097343,
#     "geohash": "dr7015n925zy",
#     "speed": 3.619999885559082,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 20
# Message Key: 073.9
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533249",
#     "offset": 74.62187096575218,
#     "course": 150.5653839111328,
#     "latitude": 40.79797554469389,
#     "longitude": -74.47835985704447,
#     "geohash": "dr7015n92mve",
#     "speed": 0.2199999988079071,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 21
# Message Key: 077.1
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533246",
#     "offset": 77.62187096575218,
#     "course": 150.5653839111328,
#     "latitude": 40.797983394573336,
#     "longitude": -74.4783637483364,
#     "geohash": "dr7015n92r6f",
#     "speed": 0.27000001072883606,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 22
# Message Key: 081.4
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533241",
#     "offset": 82.62187096575218,
#     "course": 152.34779357910156,
#     "latitude": 40.798284502427755,
#     "longitude": -74.47858440294144,
#     "geohash": "dr7015n75pqq",
#     "speed": 12.800000190734863,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 23
# Message Key: 085.1
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533238",
#     "offset": 85.62187096575218,
#     "course": 152.34779357910156,
#     "latitude": 40.79859072722529,
#     "longitude": -74.47879707231947,
#     "geohash": "dr7015njn0x9",
#     "speed": 13.329999923706055,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 24
# Message Key: 088.3
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533235",
# ...
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 42
# Message Key: 030.4
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320423",
#     "offset": 31.077912529556645,
#     "course": 67.5,
#     "latitude": 40.67889422182057,
#     "longitude": -73.82009002386948,
#     "geohash": "dr5x2jmgepx2",
#     "speed": 11.09000015258789,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 43
# Message Key: 033.7
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320419",
#     "offset": 35.07791252955665,
#     "course": 103.0078125,
#     "latitude": 40.678800176866986,
#     "longitude": -73.82046670659801,
#     "geohash": "dr5x2jme4myr",
#     "speed": 4.820000171661377,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 44
# Message Key: 037.7
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320416",
#     "offset": 38.07791252955665,
#     "course": 158.90625,
#     "latitude": 40.678862412498034,
#     "longitude": -73.82057458169183,
#     "geohash": "dr5x2jm7xctf",
#     "speed": 3.450000047683716,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 45
# Message Key: 041.5
# Message Value:
#   {
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320412",
#     "offset": 42.07791252955665,
#     "course": 158.5546875,
#     "latitude": 40.67892904862825,
#     "longitude": -73.82060819312355,
#     "geohash": "dr5x2jm7zjuz",
#     "speed": 0.8700000047683716,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 46
# Message Key: 045.4
# Message Value:
#   {
#     "id": "c44516bd325cb60548b431b4d6409dde",
#     "ride_id": "b063cb65cd8446b83b4a09d4db2646c8",
#     "uuid": "c6608d4cb9224aa3a0763a835e6c8788",
#     "timestamp": "1970-01-01 00:25:06.796335",
#     "offset": 46.7677702566351,
#     "course": 36.619529724121094,
#     "latitude": 40.695276003407606,
#     "longitude": -73.92459313225648,
#     "geohash": "dr5rtb3g0jk1",
#     "speed": 11.010000228881836,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "0d4d27dc-360b-4bb2-9b0c-bf84be964785.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 47
# Message Key: 049.5
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471334",
#     "offset": 49.64691734364177,
#     "course": 218.3203125,
#     "latitude": 40.6138375355309,
#     "longitude": -73.98511720828151,
#     "geohash": "dr5rh3t8vb41",
#     "speed": 13.630000114440918,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 48
# Message Key: 052.5
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471330",
#     "offset": 53.64691734364177,
#     "course": 218.671875,
#     "latitude": 40.61420659072754,
#     "longitude": -73.98473197601174,
#     "geohash": "dr5rh3tfyuc7",
#     "speed": 12.350000381469727,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 49
# Message Key: 056.4
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471327",
#     "offset": 56.64691734364177,
#     "course": 217.6171875,
#     "latitude": 40.614466765001985,
#     "longitude": -73.98445554084515,
#     "geohash": "dr5rh3whmjr7",
#     "speed": 12.40999984741211,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 50
# Message Key: 060.1
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533263",
#     "offset": 60.62187096575219,
#     "course": 158.39361572265625,
#     "latitude": 40.79774731473191,
#     "longitude": -74.47818030692527,
#     "geohash": "dr7015n8he7d",
#     "speed": 0.0,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 51
# Message Key: 063.8
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533259",
#     "offset": 64.62187096575218,
#     "course": 158.39361572265625,
#     "latitude": 40.797748056487556,
#     "longitude": -74.47818069351581,
#     "geohash": "dr7015n8he7q",
#     "speed": 0.33000001311302185,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 52
# Message Key: 066.7
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533256",
#     "offset": 67.62187096575218,
#     "course": 157.17140197753906,
#     "latitude": 40.797799978465186,
#     "longitude": -74.47821074543842,
#     "geohash": "dr7015n87vhu",
#     "speed": 5.050000190734863,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 53
# Message Key: 070.9
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533252",
#     "offset": 71.62187096575218,
#     "course": 150.5653839111328,
#     "latitude": 40.797965233074194,
#     "longitude": -74.47836771097343,
#     "geohash": "dr7015n925zy",
#     "speed": 3.619999885559082,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 54
# Message Key: 073.9
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533249",
#     "offset": 74.62187096575218,
#     "course": 150.5653839111328,
#     "latitude": 40.79797554469389,
#     "longitude": -74.47835985704447,
#     "geohash": "dr7015n92mve",
#     "speed": 0.2199999988079071,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 55
# Message Key: 077.1
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533246",
#     "offset": 77.62187096575218,
#     "course": 150.5653839111328,
#     "latitude": 40.797983394573336,
#     "longitude": -74.4783637483364,
#     "geohash": "dr7015n92r6f",
#     "speed": 0.27000001072883606,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 56
# Message Key: 081.4
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533241",
#     "offset": 82.62187096575218,
#     "course": 152.34779357910156,
#     "latitude": 40.798284502427755,
#     "longitude": -74.47858440294144,
#     "geohash": "dr7015n75pqq",
#     "speed": 12.800000190734863,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 57
# Message Key: 085.1
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533238",
#     "offset": 85.62187096575218,
#     "course": 152.34779357910156,
#     "latitude": 40.79859072722529,
#     "longitude": -74.47879707231947,
#     "geohash": "dr7015njn0x9",
#     "speed": 13.329999923706055,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 58
# Message Key: 088.3
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533235",
#     "offset": 88.62187096575218,
#     "course": 152.34779357910156,
#     "latitude": 40.79890645599764,
#     "longitude": -74.47901202142467,
#     "geohash": "dr7015nnc5rk",
#     "speed": 12.880000114440918,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 59
# Message Key: 091.7
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256879",
#     "offset": 92.44092680518746,
#     "course": 177.01223754882812,
#     "latitude": 32.17064176487744,
#     "longitude": 34.89354603885206,
#     "geohash": "sv8z402xwd39",
#     "speed": 9.029999732971191,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 60
# Message Key: 094.7
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533228",
#     "offset": 95.62187096575218,
#     "course": 152.5463409423828,
#     "latitude": 40.79941309859722,
#     "longitude": -74.4793609798836,
#     "geohash": "dr7015mcc1g7",
#     "speed": 0.7699999809265137,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 61
# Message Key: 098.8
# Message Value:
#   {
#     "id": "19a14c90289c3d32892a514eedb80966",
#     "ride_id": "22832655a94b8d9edbb2e98e32763b19",
#     "uuid": "f7974037e1c44ec1b04b69b2d1159b28",
#     "timestamp": "1970-01-01 00:25:03.533224",
#     "offset": 99.62187096575218,
#     "course": 152.5463409423828,
#     "latitude": 40.79941204519561,
#     "longitude": -74.47937030601163,
#     "geohash": "dr7015mcbcsk",
#     "speed": 0.0,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "d9861ce7-76b0-47b8-a438-9ca89fce1ea4.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 62
# Message Key: 102.5
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256868",
#     "offset": 103.44092680518744,
#     "course": 177.01223754882812,
#     "latitude": 32.17115876513905,
#     "longitude": 34.89351052712796,
#     "geohash": "sv8z408dtdxj",
#     "speed": 8.079999923706055,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 63
# Message Key: 106.0
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256864",
#     "offset": 107.44092680518744,
#     "course": 177.01223754882812,
#     "latitude": 32.171575709980395,
#     "longitude": 34.89347708670073,
#     "geohash": "sv8z408thbqk",
#     "speed": 13.220000267028809,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 64
# Message Key: 109.9
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256861",
#     "offset": 110.44092680518744,
#     "course": 177.260498046875,
#     "latitude": 32.17191991618058,
#     "longitude": 34.893406696212615,
#     "geohash": "sv8z408x529c",
#     "speed": 12.529999732971191,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 65
# Message Key: 113.2
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256857",
#     "offset": 114.44092680518744,
#     "course": 177.26060485839844,
#     "latitude": 32.172298555134,
#     "longitude": 34.89338092083675,
#     "geohash": "sv8z40b94xns",
#     "speed": 8.220000267028809,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 66
# Message Key: 117.2
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256854",
#     "offset": 117.44092680518744,
#     "course": 173.62954711914062,
#     "latitude": 32.17255112942276,
#     "longitude": 34.893348562903604,
#     "geohash": "sv8z40bd9ynq",
#     "speed": 6.610000133514404,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: BondaAnjani-locations
#   Partition: 0
#   Offset: 67
# Message Key: 121.4
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256849",
#     "offset": 122.44092680518744,
#     "course": 170.8992156982422,
#     "latitude": 32.1727997675769,
#     "longitude": 34.89331201491426,
#     "geohash": "sv8z40bs1he4",
#     "speed": 5.829999923706055,
#     "accuracy": 5.0,
#     "timelapse": false,
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }

# %%
# Close the consumer, waiting indefinitely for any needed cleanup.
consumer.close()
